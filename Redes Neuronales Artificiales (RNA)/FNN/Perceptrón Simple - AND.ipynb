# %% [markdown]
# **Definir la función de activación o transferencia a utilizar:**

# %% [markdown]
# Para este caso se utiliza la función Signo

# %%
def fsigno(x):
  if x>0:
    return 1
  else:
    return -1

# %% [markdown]
# **Se define la taza de aprendizaje (n)**

# %%
#tasa de aprendizaje
n = 0.5

# %% [markdown]
# **Definimos los pesos de manera aleatoria, considerando una semilla aleatoria igual a 50**

# %% [markdown]
# importamos la librería random.

# %%
import random
random.seed(50) # esto es la semilla que tengo que cambiar de acuerdo a lo que piden
w1 = random.random()
w2 = random.random()
s  = random.random() #sesgo: peso del bias
print("w1 = ", w1)
print("w2 = ",w2)
print("sesgo = ",s)
# Out:
# w1 =  0.4975365687586023
# w2 =  0.2661737230725406
# sesgo =  0.6374111614436909

# %% [markdown]
# ### **Época 1**

# %% [markdown]
# se utilizarán para cada época:
# * cada una de las entradas (X) con su respectivo peso (W) y también
# * la Regla de Aprendiaje del perceptrón simple, para calcular los nuevos pesos.
# hasta que los pesos no cambien.

# %% [markdown]
# ![regla.JPG](attachment:regla.JPG)

# %% [markdown]
# ![Captura3.JPG](attachment:Captura3.JPG)

# %% [markdown]
# ![tabla.JPG](attachment:tabla.JPG)

# %% [markdown]
# **primera entrada con su salida**

# %%
x1 = 1
x2 = 1
z = 1
print("suma ponderada:", x1*w1 + x2*w2 + 1*s)
y = fsigno(x1*w1 + x2*w2 + 1*s) #al aplicar la función de activación obtengo la salida o valor predicho.
print("valor predicho: y =", y)
# Out:
# suma ponderada: 1.401121453274834
#  valor predicho: y = 1

# %% [markdown]
# calculamos los nuevos pesos con la regla de aprendizaje

# %%
w1 = w1 + n*(z-y)*x1
w2 = w2 + n*(z-y)*x2
s = s + n*(z-y)*1
print("w1 = ", w1)
print("w2 = ",w2)
print("sesgo = ",s)
# Out:
# w1 =  0.4975365687586023
# w2 =  0.2661737230725406
# sesgo =  0.6374111614436909

# %% [markdown]
# **segunda entrada con su salida**

# %%
x1 = 1
x2 = -1
z = -1
print(x1*w1 + x2*w2 + 1*s)
y = fsigno(x1*w1 + x2*w2 + 1*s)
print("y =", y)
# Out:
# 0.8687740071297526
# y = 1

# %%
w1 = w1 + n*(z-y)*x1
w2 = w2 + n*(z-y)*x2
s = s + n*(z-y)*1
print("w1 = ", w1)
print("w2 = ",w2)
print("sesgo = ",s)
# Out:
# w1 =  -0.5024634312413977
# w2 =  1.2661737230725407
# sesgo =  -0.3625888385563091

# %% [markdown]
# **tercera entrasa con su salida**

# %%
x1 = - 1
x2 = 1
z = -1
print(x1*w1 + x2*w2 + 1*s)
y = fsigno(x1*w1 + x2*w2 + 1*s)
print("y =", y)
# Out:
# 1.4060483157576296
# y = 1

# %%
w1 = w1 + n*(z-y)*x1
w2 = w2 + n*(z-y)*x2
s = s + n*(z-y)*1
print("w1 = ", w1)
print("w2 = ",w2)
print("sesgo = ",s)
# Out:
# w1 =  0.4975365687586023
# w2 =  0.2661737230725407
# sesgo =  -1.362588838556309

# %% [markdown]
# **cuarda entrada con su salida**

# %%
x1 = - 1
x2 = - 1
z = -1
print(x1*w1 + x2*w2 + 1*s)
y = fsigno(x1*w1 + x2*w2 + 1*s)
print("y =", y)
# Out:
# -2.126299130387452
# y = -1

# %%
w1 = w1 + n*(z-y)*x1
w2 = w2 + n*(z-y)*x2
s = s + n*(z-y)*1
print("w1 = ", w1)
print("w2 = ",w2)
print("sesgo = ",s)
# Out:
# w1 =  0.4975365687586023
# w2 =  0.2661737230725407
# sesgo =  -1.362588838556309

# %% [markdown]
# ### Época 2

# %%
x1 = 1
x2 = 1
z = 1
print(x1*w1 + x2*w2 + 1*s)
y = fsigno(x1*w1 + x2*w2 + 1*s)
print("y =", y)
# Out:
# -0.5988785467251659
# y = -1

# %%
w1 = w1 + n*(z-y)*x1
w2 = w2 + n*(z-y)*x2
s = s + n*(z-y)*1
print("w1 = ", w1)
print("w2 = ",w2)
print("sesgo = ",s)
# Out:
# w1 =  1.4975365687586022
# w2 =  1.2661737230725407
# sesgo =  -0.36258883855630897

# %%
x1 = 1
x2 = -1
z = -1
print(x1*w1 + x2*w2 + 1*s)
y = fsigno(x1*w1 + x2*w2 + 1*s)
print("y =", y)
# Out:
# -0.1312259928702475
# y = -1

# %%
w1 = w1 + n*(z-y)*x1
w2 = w2 + n*(z-y)*x2
s = s + n*(z-y)*1
print("w1 = ", w1)
print("w2 = ",w2)
print("sesgo = ",s)
# Out:
# w1 =  1.4975365687586022
# w2 =  1.2661737230725407
# sesgo =  -0.36258883855630897

# %%
x1 = - 1
x2 =  1
z = -1
print(x1*w1 + x2*w2 + 1*s)
y = fsigno(x1*w1 + x2*w2 + 1*s)
print("y =", y)
# Out:
# -0.5939516842423704
# y = -1

# %%
w1 = w1 + n*(z-y)*x1
w2 = w2 + n*(z-y)*x2
s = s + n*(z-y)*1
print("w1 = ", w1)
print("w2 = ",w2)
print("sesgo = ",s)
# Out:
# w1 =  1.4975365687586022
# w2 =  1.2661737230725407
# sesgo =  -0.36258883855630897

# %%
x1 = - 1
x2 = - 1
z = - 1
print(x1*w1 + x2*w2 + 1*s)
y = fsigno(x1*w1 + x2*w2 + 1*s)
print("y =", y)
# Out:
# -3.126299130387452
# y = -1

# %%
w1 = w1 + n*(z-y)*x1
w2 = w2 + n*(z-y)*x2
s = s + n*(z-y)*1
print("w1 = ", w1)
print("w2 = ",w2)
print("sesgo = ",s)
# Out:
# w1 =  1.4975365687586022
# w2 =  1.2661737230725407
# sesgo =  -0.36258883855630897

# %% [markdown]
# ### Época 3

# %%
x1 = 1
x2 = 1
z = 1
print(x1*w1 + x2*w2 + 1*s)
y = fsigno(x1*w1 + x2*w2 + 1*s)
print("y =", y)
# Out:
# 2.401121453274834
# y = 1

# %%
w1 = w1 + n*(z-y)*x1
w2 = w2 + n*(z-y)*x2
s = s + n*(z-y)*1
print("w1 = ", w1)
print("w2 = ",w2)
print("sesgo = ",s)
# Out:
# w1 =  1.4975365687586022
# w2 =  1.2661737230725407
# sesgo =  -0.36258883855630897

# %% [markdown]
# **Ya no hay más cambios. No es necesario probar con el resto de entradas de la época porque ya han sidoprobados satisfactoriamente con los mismos PESOS.**

# %% [markdown]
# Ahora probamos la Red Neuronal Artificial Simple, lugo de haber identificado los **Pesos sinápticos (w)** apropiados:

# %% [markdown]
# * Creo una función (fincionAnd) con dos entradas y uso la función fsigno definido en la primera línea.
# * usando los pesos apropiados ya calculados.(con esos pesos voy a trabajar XD)

# %%
def funcionAnd(x1 , x2):
  #y = fsigno (x1*1.4975365687586022 + x2*1.2661737230725407 + 1*(-0.36258883855630897))
  y = fsigno (x1*w1 + x2*w2 + 1*(s))
  if y == 1:
    return "V"
  else:
    return "F"

# %% [markdown]
# Probamos:

# %%
#Prueba
print("V and V: ",funcionAnd(1,1))
print("V and F: ",funcionAnd(1,-1))
print("F and V: ",funcionAnd(-1,1))
print("F and F: ",funcionAnd(-1,-1))
# Out:
# V and V:  V
# V and F:  F
# F and V:  F
# F and F:  F
